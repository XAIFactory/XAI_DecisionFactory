# %%
from ProfileGen import ds_profile_generator
from ContextAgent import execute_agent_context
from ProfilerAgent import run_profile_agent

# %%
def main():

    # ---------------------------------------------------------
    # STEP 1: Data Science profiling module
    # Generates customer profiles, SHAP importance,
    # clustering, decision rules, profile summary stats,
    #and odds ratios
    # ---------------------------------------------------------
    res1 = ds_profile_generator(
        work_directory="XAI_DecisionFactory", #work directory where the folder containing the "main" is stored
        file_path="XDF_abt_input/ActionForge.csv",        # Input dataset (CSV format)
        sep=";",                                         # CSV column separator
        decimal=",",                                     # Decimal separator
        id_col="IDCLI",                                  # Unique identifier column
        target_score_col="score",                        # Model score column
        threshold=10,                                    # Percentile threshold for HP/LP definition (10: top10% will be marked as HP(high Propensity)"
        min_profile_size=0.06,                           # Minimum profile size (as % of total population)
        eps=0.25,                                        # DBSCAN neighborhood radius - clustering parameters
        output_path="XDF_analytical_output"               # Output directory for all generated artifacts
    )

    # ---------------------------------------------------------
    # STEP 2: Context ingestion agent
    # Loads business, general and feature-level context
    # to enrich the interpretation layer
    # ---------------------------------------------------------
    res2 = execute_agent_context(
        work_directory="XAI_DecisionFactory",     #work directory where the folder containing the "main" is stored
        general_csv="XDF_context_infos/general_context.csv",   # General contextual information
        business_csv="XDF_context_infos/biz_context.csv",      # Business context and domain knowledge
        features_csv="XDF_context_infos/features_context.csv"  # Feature descriptions and human-readable meanings
    )

    # ---------------------------------------------------------
    # STEP 3: Profile interpretation agent
    # Combines analytical outputs with context to generate
    # explainable and actionable insights at profile level
    # ---------------------------------------------------------
    res3 = run_profile_agent(
        work_directory="XAI_DecisionFactory", #work directory where the folder containing the "main" is stored
        oddratio_csv="XDF_analytical_output/oddsratio.csv",          # Odds ratios from logistic model
        profile_features_csv="XDF_analytical_output/PROFILE_FEATURES.csv",  # Decision tree feature importance
        profile_stats_csv="XDF_analytical_output/PROFILE_STATS.csv",        # Aggregated statistics per profile
        profile_rules_csv="XDF_analytical_output/PROFILE_RULES.csv",        # Decision tree rules per profile
        shap_importance_json="XDF_analytical_output/shap_importance.json",  # Global SHAP importance
        context_memory="context_memory.json",                             # Context generated by previous agent
        sep=","                                                           # CSV separator
    )

    # ---------------------------------------------------------
    # OUTPUT RESULTS
    # ---------------------------------------------------------
    print("Step 1 - Profiler Output:")
    print(res1)

    print("\nStep 2 - Context Agent Output:")
    print(res2)

    print("\nStep 3 - Profile Agent Output:")
    print(res3)


if __name__ == "__main__":
    main()
# Out:
# C:\Users\luigi\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\luigi\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 2 is smaller than n_iter=10. Running 2 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\luigi\anaconda3\Lib\site-packages\shap\explainers\_tree.py:620: UserWarning: LightGBM binary classifier with TreeExplainer shap values output has changed to a list of ndarray
#   warnings.warn(
# C:\Users\luigi\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:317: UserWarning: The total space of parameters 12 is smaller than n_iter=15. Running 12 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# C:\Users\luigi\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:1272: FutureWarning: 'multi_class' was deprecated in version 1.5 and will be removed in 1.8. From then on, it will always use 'multinomial'. Leave it to its default value to avoid this warning.
#   warnings.warn(
# PIPELINE COMPLETED SUCCESSFULLY
# PROFILES GENERATED: 3
#   -> Outputs saved in: XDF_analytical_output/
# ============================================================
#   CONTEXT AGENT — powered by Ollama (local)
#   Model: phi3:mini
# ============================================================
#
# [INFO] Reading CSV context files...
# [INFO] Sending context to the model (this may take a few seconds)...
#
#
# ────────────────────────────────────────────────────────────
# [AGENT UNDERSTANDING]
#
# ## Agent Role: Explainer-Agent in Data Science & Marketing Strategy Development for E‑Mobility Retail Sector
# The agent's role is to serve as an Explanation Agent specializing in the integration of data science and behavioral psychology within marketing strategies, particularly focusing on personalized sales tactics for electric scooters. The primary tasks involve analyzing customer profiles generated by machine learning models using AI Explainable Intelligence (XAI) to extract actionable insights aimed at increasing purchase propensities and revenue growth while ensidering ethical marketing practices, sustainability awareness among consumers, and digital engagement as a form of relationship building.
#
# ## General Context: E-Mobility Retail Sector Overview & Constraints
# - Market Dynamics: Rapidly growing e-mobility sector with increasing demand for electric scooters in urban areas; competition is fierce among retail and branded outlets as well as online platforms.
# - Consumer Behavior Trends: Increasing environmental awareness influencing purchase decisions, alongside a shift towards digital engagement channels such as social media and app usage for product discovery.
# - Business Constraints: Limited resources require focused marketing efforts on high-impact customer segments; transparency in AI decision-making is crucial to maintain consumer trust without overstating the influence of data analytics or predictive model outputs, as per XAI principles and GDPR compliance.
#
# ## Business Context: Marketing & Sales Strategy Development for Electric Scooters
# Key Objectives: Increase sales conversion rates within targeted customer segments; elevate brand awareness among environmentally conscious consumers interested in sustainable transportation options like electric scooters. KPIs may include Customer Acquisition Cost (CAC), Conversion Rate, Average Order Value (AOV), and Net Promoter Score for the Electric Scooter lineup.
# - Strategic Priorities: Focus on personalization in marketing; leverage data to understand customer preferences, behaviors, and digital engagement patterns that signal a high likelihood of purchase intent or loyalty towards electric scooters over traditional alternatives (bikes/scooters).
# - Operational Drivers: Efficient segmentation based on RFM analysis; targeted content creation for various customer life cycle stages aligned with their digital engagement levels. Emphasize ecological benefits and sustainability in messaging to resonate with environmentally aware demographics, especially those living or frequenting large cities (as indicated by 'GrandCentr' feature).
# - Constraints: Budget limitations restrict extensive market research; reliance on reliable ML model outputs for customer profiling. Maintaining consumer trust through transparent AI usage is paramount to avoid backlash against perceived invasive data practices or manipulative tactics.
#
# ## Purpose of the Agent in Marketing Strategy
# The agent's purpose revolves around providing actionable insights for tailored marketing and sales strategies that cater specifically to high-impact customer segments identified through RFM analysis, environmental sensitivity scores (GreenSurveyScore), digital engagement levels ('Engagement'), and other behavioral indicators. These efforts should lead directly towards increased conversions in electric scooter purchases while reinforcing the brand's commitment to sustainability—a selling point for eco-conscious consumers.
#
# ## Included Features: Insights into Customer Behavior and Valuation
# Each feature represents a specific aspect of customer data, which helps in building detailed profiles that can inform targeted marketing strategies as follows:
#
# | Variable Name                     | Measures           | Represents            | Relationship to Business Problem                | Importance for Marketing Strategy          |
# |-------------------------------|--------------------|-----------------------|-----------------------------------------|-------------------------------------|
# | IDCLI (Raw Client ID)             | Unique identifier   |                    | Used as a reference point in profiling, ensuring data integrity and confidentiality. Not directly used for marketing strategies due to its anonymized nature but essential for customer privacy.         |
# | Professione (Client Job)          | Client's occupation | Socio-Demographic    | Offers insights into purchasing power, influencing the type of electric scooter models and marketing messages that resonate with different professional demographics; informs pricing strategy.                   |
# | Capacita_d_
#
# ────────────────────────────────────────────────────────────
#
# Enter feedback to refine the analysis (or 'yes' to confirm and exit):
# You ->  yes
# [INFO] Understanding confirmed. Saving memory...
#
# [INFO] Extracting final structured memory...
#
# [OK] Memory saved to: context_memory.json
#
# [FINAL MEMORY]
# {
#   "role": "Explainer-Agent in Data Science & Marketing Strategy Development for E-Mobility Retail Sector",
#   "general_context": "Emerging e-mobility sector with a focus on personalized marketing strategies to boost electric scooter sales among environmentally conscious consumers, leveraging data science and behavioral psychology.",
#   "business_context": "Marketing & Sales Strategy Development for Electric Scooters",
#   "scope": "Increase conversion rates within targeted customer segments by understanding preferences, behaviors, and digital engagement patterns to resonate with eco-conscious demographics.",
#   "features_and_concepts": [
#     "IDCLI (Raw Client ID)",
#     "Professione (Client Job)",
#     "Capacita_d_"
#   ],
#   "other": "Efficiency in segmentation based on RFM analysis and targeted content creation for various customer life cycle stages, emphasizing ecological benefits to resonate with environmentally aware demographics while maintaining consumer trust through transparent AI usage."
# }
# ============================================================
#   PROFILE ANALYST AGENT — powered by Ollama
#   Model : phi3:mini
#   Folder: C:\Users\luigi\XAI_DecisionForge
# ============================================================
#
# [INFO] Loading business context memory...
#   [OK] Context memory loaded from 'context_memory.json'
#
# [INFO] Loading profile CSV files...
#   [OK] XDF_analytical_output/oddsratio.csv — 3 rows, 37 cols
#   [OK] XDF_analytical_output/PROFILE_FEATURES.csv — 6 rows, 2 cols
#   [OK] XDF_analytical_output/PROFILE_STATS.csv — 3 rows, 20 cols
#   [OK] XDF_analytical_output/PROFILE_RULES.csv — 7 rows, 3 cols
#
# [INFO] Loading SHAP importance JSON...
#   [OK] XDF_analytical_output/shap_importance.json — SHAP data loaded.
#   [OK] Profile column: 'Profile_ID' — 3 unique profiles
#
# [INFO] Profiles to analyze: ['4', '7', 'Generic']
#        Total: 3
#
# ============================================================
#   PROFILE 1 of 3: '4'
# ============================================================
#
#   [INFO] Analyzing profile: '4'...
#
# ────────────────────────────────────────────────────────────
# [PROFILE DESCRIPTION — ID: 4]
#
# ### Profile Name and Tagline | ID: 4
# - **Name**: The Green Advocate Shoppers
# - **Tagline**: Environmentally conscious consumers with high loyalty potentials, scoring above average on eco-friendly product engagement and lifetime value.
#
# ---
# ### Who Are They? (Storytelling)
# The profile ID 4 represents a unique segment of customers within the electric scooter market characterized by their strong environmental values and higher propensity to spend, as indicated by an RFM_Score of 6.230769230769231 (meaning they are relatively high in terms of recency, frequency, and monetary value). These individuals have a lifetime value (LTV) score averaging at 2.3461538461538463 and spend an average amount on electric scooters each month calculated from the "Numero di Prodtti Aquistati negli ultimi 12 mesi" of approximately $1,807.69 (meaning they are consistent purchasers). They have been engaging with eco-friendly products for an average age or tenure ("Eta") of about 26 years and a digitalization level suggesting familiarity with online shopping environments at around the median score of 3.1153846153846154 (indicating they are likely to be comfortable navigating e-commerce platforms). On average, customers in this profile have an engagement rate of about 71.80% with digital content related to sustainability and electric mobility products at around the median score of 0.7180173147692308 (indicating a high level of interest). The Green Survey Score for this profile is notably higher than average, scoring an impressive 8.327705800115384, which means that they are more likely to prioritize eco-friendly products in their purchasing decisions and have a strong environmental consciousness score of 6.230769230769231 (meaning this is not just an interest but also part of their lifestyle). The average margin over the last 12 months for these customers stands at $440, suggesting they are potentially high-spending individuals in our target market.
# The main difference between Profile ID: 4 and other profiles lies in its distinctly higher scores on GreenSurveyScore (8.327705800115384) compared to the rest of the customer base, indicating a strong alignment with eco-friendly values that can be leveraged for targeted marketing strategies aimed at boosting electric scooter sales within this environmentally conscious demographic.
#
# ---
# ### Key Data Insights
# - **RFM_Score** = 6.230769230769231 -> Indicates a customer who is active, frequent in purchases and highly valuable over time for the business. Targeting them with loyalty programs could increase their lifetime value further.
# - **LTV** = 2.3461538461538463 -> Suggests these customers have a high potential to contribute significantly to revenue, making personalized upgrades and cross-selling opportunities in electric scooters appealing for them.
# - **Eta** = 26.423076923076923 ->
#
# ────────────────────────────────────────────────────────────
#
# Enter feedback to refine, or 'yes' to confirm:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 64
#      60     print(res3)
#      63 if __name__ == "__main__":
# ---> 64     main()
#
# Cell In[3], line 39, in main()
#      27 res2 = execute_agent_context(
#      28     work_directory="C:\\Users\\luigi\\XAI_DecisionForge",
#      29     general_csv="XDF_context_infos/general_context.csv",   # General contextual information
#      30     business_csv="XDF_context_infos/biz_context.csv",      # Business context and domain knowledge
#      31     features_csv="XDF_context_infos/features_context.csv"  # Feature descriptions and human-readable meanings
#      32 )
#      34 # ---------------------------------------------------------
#      35 # STEP 3: Profile interpretation agent
#      36 # Combines analytical outputs with context to generate
#      37 # explainable and actionable insights at profile level
#      38 # ---------------------------------------------------------
# ---> 39 res3 = run_profile_agent(
#      40     work_directory="C:\\Users\\luigi\\XAI_DecisionForge",
#      41     oddratio_csv="XDF_analytical_output/oddsratio.csv",          # Odds ratios from logistic model
#      42     profile_features_csv="XDF_analytical_output/PROFILE_FEATURES.csv",  # Decision tree feature importance
#      43     profile_stats_csv="XDF_analytical_output/PROFILE_STATS.csv",        # Aggregated statistics per profile
#      44     profile_rules_csv="XDF_analytical_output/PROFILE_RULES.csv",        # Decision tree rules per profile
#      45     shap_importance_json="XDF_analytical_output/shap_importance.json",  # Global SHAP importance
#      46     context_memory="context_memory.json",                             # Context generated by previous agent
#      47     sep=","                                                           # CSV separator
#      48 )
#      50 # ---------------------------------------------------------
#      51 # OUTPUT RESULTS
#      52 # ---------------------------------------------------------
#      53 print("Step 1 - Profiler Output:")
#
# File ~\XAI_DecisionForge\Main_Modules\ProfilerAgent.py:639, in run_profile_agent(work_directory, oddratio_csv, profile_features_csv, profile_stats_csv, profile_rules_csv, shap_importance_json, context_memory, sep)
#     636 print(f"  PROFILE {i} of {len(profiles)}: '{profile_id}'")
#     637 print(f"{'=' * 60}")
# --> 639 result = analyze_profile(
#     640     context, profile_id, shap_txt,
#     641     df_stats, df_features, df_oddratio, df_rules
#     642 )
#     643 results.append(result)
#     644 print(f"\n[OK] Profile '{profile_id}' confirmed — moving to next.")
#
# File ~\XAI_DecisionForge\Main_Modules\ProfilerAgent.py:524, in analyze_profile(context, profile_id, shap_txt, df_stats, df_features, df_oddratio, df_rules)
#     521 history.append({"role": "assistant", "content": response})
#     523 # Interactive feedback loop — user refines or confirms with "yes"
# --> 524 final_description = feedback_loop(
#     525     response, history,
#     526     label=f"PROFILE DESCRIPTION — ID: {profile_id}"
#     527 )
#     529 return {
#     530     "profile_id":  str(profile_id),
#     531     "description": final_description
#     532 }
#
# File ~\XAI_DecisionForge\Main_Modules\ProfilerAgent.py:343, in feedback_loop(initial_response, history, label)
#     340 print(f"\n{'─' * 60}")
#     341 print(f"\nEnter feedback to refine, or '{MAGIC_WORD}' to confirm:\n")
# --> 343 user_input = input("You -> ").strip()
#     345 if user_input.lower() == MAGIC_WORD:
#     346     print("[OK] Confirmed.")
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1275, in Kernel.raw_input(self, prompt)
#    1273     msg = "raw_input was called, but this frontend does not support input requests."
#    1274     raise StdinNotImplementedError(msg)
# -> 1275 return self._input_request(
#    1276     str(prompt),
#    1277     self._parent_ident["shell"],
#    1278     self.get_parent("shell"),
#    1279     password=False,
#    1280 )
#
# File ~\anaconda3\Lib\site-packages\ipykernel\kernelbase.py:1320, in Kernel._input_request(self, prompt, ident, parent, password)
#    1317 except KeyboardInterrupt:
#    1318     # re-raise KeyboardInterrupt, to truncate traceback
#    1319     msg = "Interrupted by user"
# -> 1320     raise KeyboardInterrupt(msg) from None
#    1321 except Exception:
#    1322     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
